# %%
pip install tensorflow gradio
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting gradio
#   Using cached gradio-4.41.0-py3-none-any.whl.metadata (15 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow)
#   Using cached h5py-3.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow)
#   Using cached ml_dtypes-0.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in /home/suryansh/myenv/lib/python3.12/site-packages (from tensorflow) (24.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Using cached protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/suryansh/myenv/lib/python3.12/site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.65.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Using cached tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.2.0 (from tensorflow)
#   Using cached keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from gradio) (4.4.0)
# Collecting fastapi (from gradio)
#   Using cached fastapi-0.112.0-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Using cached ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.3.0 (from gradio)
#   Using cached gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /home/suryansh/myenv/lib/python3.12/site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Using cached huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jinja2<4.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from gradio) (2.1.5)
# Collecting matplotlib~=3.0 (from gradio)
#   Using cached matplotlib-3.9.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting orjson~=3.0 (from gradio)
#   Using cached orjson-3.10.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Collecting pandas<3.0,>=1.0 (from gradio)
#   Using cached pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pillow<11.0,>=8.0 (from gradio)
#   Using cached pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pydantic>=2.0 (from gradio)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting pydub (from gradio)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Using cached python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Using cached ruff-0.5.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: urllib3~=2.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from gradio) (2.2.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Using cached uvicorn-0.30.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting fsspec (from gradio-client==1.3.0->gradio)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio)
#   Using cached websockets-12.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: idna>=2.8 in /home/suryansh/myenv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /home/suryansh/myenv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: certifi in /home/suryansh/myenv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/suryansh/myenv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/suryansh/myenv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Collecting filelock (from huggingface-hub>=0.19.3->gradio)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.19.3->gradio)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting rich (from keras>=3.2.0->tensorflow)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.2.0->tensorflow)
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.2.0->tensorflow)
#   Using cached optree-0.12.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
# Collecting contourpy>=1.0.1 (from matplotlib~=3.0->gradio)
#   Using cached contourpy-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib~=3.0->gradio)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib~=3.0->gradio)
#   Using cached fonttools-4.53.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib~=3.0->gradio)
#   Using cached kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib~=3.0->gradio)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/suryansh/myenv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=1.0->gradio)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic>=2.0->gradio)
#   Using cached pydantic_core-2.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/suryansh/myenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.2.0->tensorflow)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/suryansh/myenv/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached tensorflow-2.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.4 MB)
# Using cached gradio-4.41.0-py3-none-any.whl (12.6 MB)
# Using cached gradio_client-1.3.0-py3-none-any.whl (318 kB)
# Using cached tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.65.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# Using cached h5py-3.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Using cached huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached keras-3.4.1-py3-none-any.whl (1.1 MB)
# Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
# Using cached matplotlib-3.9.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached ml_dtypes-0.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached orjson-3.10.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Using cached ruff-0.5.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Using cached tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached uvicorn-0.30.5-py3-none-any.whl (62 kB)
# Using cached wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
# Using cached fastapi-0.112.0-py3-none-any.whl (93 kB)
# Using cached ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached contourpy-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (309 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached websockets-12.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached wheel-0.44.0-py3-none-any.whl (67 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached namex-0.0.8-py3-none-any.whl (5.8 kB)
# Using cached optree-0.12.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, pydub, namex, libclang, flatbuffers, wrapt, wheel, werkzeug, websockets, tzdata, typing-extensions, tqdm, tomlkit, termcolor, tensorboard-data-server, shellingham, semantic-version, ruff, python-multipart, pyparsing, protobuf, pillow, orjson, numpy, mdurl, markdown, kiwisolver, importlib-resources, grpcio, google-pasta, gast, fsspec, fonttools, filelock, ffmpy, cycler, click, annotated-types, aiofiles, absl-py, uvicorn, tensorboard, starlette, pydantic-core, pandas, optree, opt-einsum, ml-dtypes, markdown-it-py, huggingface-hub, h5py, contourpy, astunparse, rich, pydantic, matplotlib, gradio-client, typer, keras, fastapi, tensorflow, gradio
# Successfully installed absl-py-2.1.0 aiofiles-23.2.1 annotated-types-0.7.0 astunparse-1.6.3 click-8.1.7 contourpy-1.2.1 cycler-0.12.1 fastapi-0.112.0 ffmpy-0.4.0 filelock-3.15.4 flatbuffers-24.3.25 fonttools-4.53.1 fsspec-2024.6.1 gast-0.6.0 google-pasta-0.2.0 gradio-4.41.0 gradio-client-1.3.0 grpcio-1.65.4 h5py-3.11.0 huggingface-hub-0.24.5 importlib-resources-6.4.0 keras-3.4.1 kiwisolver-1.4.5 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 matplotlib-3.9.1.post1 mdurl-0.1.2 ml-dtypes-0.4.0 namex-0.0.8 numpy-1.26.4 opt-einsum-3.3.0 optree-0.12.1 orjson-3.10.7 pandas-2.2.2 pillow-10.4.0 protobuf-4.25.4 pydantic-2.8.2 pydantic-core-2.20.1 pydub-0.25.1 pyparsing-3.1.2 python-multipart-0.0.9 pytz-2024.1 rich-13.7.1 ruff-0.5.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.37.2 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorflow-2.17.0 termcolor-2.4.0 tomlkit-0.12.0 tqdm-4.66.5 typer-0.12.3 typing-extensions-4.12.2 tzdata-2024.1 uvicorn-0.30.5 websockets-12.0 werkzeug-3.0.3 wheel-0.44.0 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np

# Loading the model
model = tf.keras.models.load_model('digit-recognizer-model.h5')
# Out:
# 2024-08-12 21:33:15.693609: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-12 21:33:15.693994: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-12 21:33:15.696474: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-12 21:33:15.702728: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-12 21:33:15.712937: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-12 21:33:15.715949: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-12 21:33:15.724429: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-12 21:33:16.336813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-08-12 21:33:19.621606: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
from PIL import Image, ImageOps

def preprocess_image(image):
    # Invert image if needed
    if np.mean(image) > 0.5:  # Simple heuristic: if average pixel value is high, it's likely a white background
        image = 1.0 - image  # Invert the image
    return image

def predict_digit(image):
    # Convert image to grayscale and handle transparency
    if isinstance(image, np.ndarray):
        image = Image.fromarray(image).convert('L')
    else:
        image = Image.open(image).convert('L')

    # Resize the image to match the input size expected by the model (28x28 pixels)
    image = image.resize((28, 28), Image.LANCZOS)

    # Ensure the background is white if transparent
    image = ImageOps.invert(image) if image.getextrema()[-1] == 0 else image

    # Convert the image to a NumPy array and normalize pixel values to [0, 1]
    image = np.array(image) / 255.0

    # Preprocess the image (e.g., invert colors if needed)
    image = preprocess_image(image)

    # Reshape the image to add batch and channel dimensions: (1, 28, 28, 1)
    image = image.reshape(1, 28, 28, 1)

    # Predict the digit using the model
    prediction = model.predict(image)

    # Find the index of the highest probability (the predicted digit)
    predicted_digit = int(np.argmax(prediction))

    return predicted_digit

# %%
import gradio as gr

# Updated Gradio interface
interface = gr.Interface(
    fn=predict_digit,  # The function that takes input and returns output
    inputs=gr.Image(),  # Grayscale image
    # inputs=gr.Sketchpad(),  # Allows users to draw on the canvas
    outputs=gr.Label(),  # Display prediction label
    live=True  # Allow live updating as the user draws
)


# Launch the interface
interface.launch(debug=False, share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://ef3241b943c9933533.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ef3241b943c9933533.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
